# %%
# %cd /content/drive/MyDrive/gpt2
# Out:
# /content/drive/MyDrive/gpt2

# %%
# !pip install -r requirements.txt

# %%
# !python3 preprocess.py

# %%
# !python3 prepare.py

# %%
# !python3 train.py --num_train_epochs 2

# %%
# !python3 generate.py --model weights/model_trained_after_1_epochs.bin --num 671
